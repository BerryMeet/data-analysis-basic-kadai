# %%
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib

df = pd.read_csv("sample_pandas_6.csv")

def tax(x):
    return x * 1.10

tax_series = df['単価'].apply(tax)
tax_series.name = "単価（税込み）"
pd.concat([df, tax_series], axis=1)
category_df = pd.read_csv('category.csv')
df = pd.merge(df, category_df[['商品番号', 'カテゴリー']], how='inner', on='商品番号')
df['カテゴリー'].value_counts().plot(kind='bar')
plt.title('カテゴリー出現頻度')

plt.show()

df = df.groupby('商品番号')['カテゴリー'].describe()
df
# Out:
#          count unique    top freq
# 商品番号
# 1QJFO8QY    32      1     弁当   32
# 2HSTCDWM    20      1   デザート   20
# 48XMJXKO    10      1   デザート   10
# 8T7D5DQA    21      1    菓子類   21
# MESUDVWQ    17      1    菓子類   17
# QRMOGNUU    27      1     雑貨   27
# S6RE8W6X    20      1  図書・新聞   20
# X0ZE2ZMY    14      1    飲料水   14
# YY4HAAZR    17      1     弁当   17
# Z4WOOIYV    22      1    飲料水   22
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('count').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('top').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('freq').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['top'].value_counts()
#     for x_label, grp in df.groupby('count')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('count')
# _ = plt.ylabel('top')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['freq'].value_counts()
#     for x_label, grp in df.groupby('top')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('top')
# _ = plt.ylabel('freq')
